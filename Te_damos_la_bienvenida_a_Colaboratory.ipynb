# %% [markdown]
# <a href="https://colab.research.google.com/github/Cynthialara561/LabMM412/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ¿Qué son las Bibliotecas en Python?
#
#
# Las bibliotecas en Python son conjuntos de módulos, que son archivos que contienen funciones, clases y variables, diseñados para realizar tareas específicas. Estas bibliotecas proporcionan funcionalidades predefinidas para resolver problemas comunes de manera eficiente, evitando que tengas que escribir código desde cero.
#
#
# Módulo: Es un archivo con código en Python, que puede contener funciones, variables y clases.
#
#
# Biblioteca: Una biblioteca es un conjunto de módulos que agrupan funcionalidades relacionadas. Por ejemplo, una biblioteca puede contener varios módulos para operaciones matemáticas, gráficos o manejo de fechas.

# %% [markdown]
# math: Funciones matemáticas básicas.

# %%
import math
x=16
#calcular la raiz cuadrada de x
resultado= math.sqrt(x)#Funcion raiz cuadrada
print("la raiz cuadrada de 16 es: " , resultado)
# Out:
# la raiz cuadrada de 16 es:  4.0

# %% [markdown]
#  numpy: Para trabajar con arreglos y álgebra lineal.

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
#realizar una operacion sobre el array
squared = np.sqrt(arr) # raiz cuadrada de cada elemento
print ("la raices caudradas de los elementos son:" , squared)
# Out:
# la raices caudradas de los elementos son: [1.         1.41421356 1.73205081 2.        ]

# %% [markdown]
# matplotlib: Para crear gráficos y visualizaciones.

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10, 10, 100) # Generar 100 puntos de -10 a 10
y=x**2 #Funcion cuadratica
plt.plot(x,y)
plt.title("Grafico de f(x) = x^2")
plt.xlabel("x")
plt.grid(True)
plt.show()

# %% [markdown]
# scipy: Para operaciones científicas y numéricas avanzadas.

# %%
import scipy.optimize as opt
def f(x):
  return x**2 - 4 # Raiz de una funcion es 2

#encontrar la raiz de la funcion usando elmmetodo de Newton
root = opt.newton(f, 2) # Estimacion inicial de 2
print( " la raiz encontrada es: " , root)
# Out:
#  la raiz encontrada es:  2.0
